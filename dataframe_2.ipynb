# %%
import pandas as pd

# %%
data={"Name":["Sonam","Innomatics","Roshni","Shubham","Siddharth"],
"Age":[22,45,78,54,21],
"Gender":["Female","Male","Female","Male","Female"],
"Salary":[80000,56000,34000,45397,57218]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#          Name  Age  Gender  Salary
# 0       Sonam   22  Female   80000
# 1  Innomatics   45    Male   56000
# 2      Roshni   78  Female   34000
# 3     Shubham   54    Male   45397
# 4   Siddharth   21  Female   57218
